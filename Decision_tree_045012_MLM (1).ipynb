# %% [markdown]
# #Country Sales Records Decision Tree Report
#
# #About the Dataset:
#
# The dataset gives information about sales of different items in middle East, Asia, Europe, their order id, how much profit a particular item makes, total cost, sales channels (online or offline) of these items.
#
# I have taken a dataset of 100001 rows with 14 variables, satisfying the requirement of 50000 rows prescribed by our professor Mr. Amarnath Mitra.
#
# I am indeed grateful to Mr. Amarnath sir for encouraging me to learn more about Machine Learning, and constantly egging me to delve deep into this topic.
#
# With sir's guidance, I was able to complete this project of mine with greater ease.
#
# Sources used: Scikit-learn, ChatGPT(for certain codes) and Kaggle
#
#
#
#
#
# # Project Objectives and  Problem Statements
#
# 1.1 Classification of Consumer Data into Segments | Clusters | Classes using Supervised Learning Classification Algorithms
#
# 1.2. Determination of an Appropriate Classification Model (from SVM, Logistic regression, KNN and decision tree)
#
# 1.3. Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification
#
# # Description of data
#
# 1. Overview:
#
# The dataset contains information related to orders, including various input variables/features and an outcome variable, 'Order Priority'.
# Input variables consist of categorical and non-categorical features.
# 'Order Priority' serves as the outcome variable, indicating the priority level of orders.
#
#
# 2. Outcome Variable (Categorical): 'Order Priority'
#
# The 'Order Priority' variable consists of four categories: M, L, C, and H.
# Each category has approximately equal frequency, with M being the most frequent and H being the least frequent.
#
#
#
# 3. Input Variables:
#
# Categorical Variables:
#
# Nominal Categories: Region, Country, Item Type.
# Ordinal Categories: Sales Channel.
# Each categorical variable exhibits a diverse set of categories with varying frequencies and proportions.
#
# Non-Categorical Variables:
#
# 'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'.
# These variables represent numerical data related to orders, including measures such as units sold, pricing, revenue, cost, and profit.
# Measures of central tendency and dispersion reveal the distribution and variability of these numerical features.
#
# 4. Measures of Central Tendency:
#
# Mean (Average):
#
# The mean values for various non-categorical variables are as follows:
# Order ID:
# Mean:
# 5.503956×10^ 8
#
#
#
# Units Sold:
#
# Mean:
# 5001.446
#
# Unit Price:
# Mean:
#
# 266.704
#
# Unit Cost:
#
# Mean:
#
# 188.020
#
# Total Revenue:
#
# Mean:
# 1.336067×10^6
#
#
# Total Cost:
# Mean:
# 9.419755×10^5
#
#
#
# Total Profit:
#
# Mean:
#
# 3.940912×10^5
#
#
# Measures of Dispersion:
#
# Range:
#
# Range values for various non-categorical variables are as follows:
#
# Order ID:
#
# 9.999965×10^8 − 1.000089×10^8
#
#
# Units Sold:
# 10000 − 1
#
# Unit Price:
# 668.27 − 9.33
#
# Unit Cost:
# 524.96 − 6.92
#
#
# Total Revenue:
# 6.6827×10^6 − 1.866
#
# Total Cost:
# 5.249075×10^6 − 0.01384
#
# Total Profit:
# 1.7387×10^6 - 0.00482
#
#
#
# Variance and Standard Deviation:
#
# Variance and standard deviation values are provided for various non-categorical variables, indicating the dispersion around the mean.
#
# 4. Correlation Analysis:
#
# A correlation analysis indicates relationships between numerical variables.
# Positive correlations are observed between 'Units Sold' and 'Total Revenue', 'Unit Price' and 'Total Revenue', 'Unit Cost' and 'Total Revenue', and 'Total Cost' and 'Total Revenue'.
# Strong positive correlation is also noted between 'Units Sold' and 'Total Profit', 'Unit Price' and 'Total Profit', and 'Total Cost' and 'Total Profit'.
#
#
# # Analysis of Data
#
# 1. Overview:
#
#
# The dataset provided consists of sales records with various features such as region, country, item type, sales channel, order priority, order date, etc. The data seems to be preprocessed, as there are no missing values or outliers. Below is an analysis of different aspects of the dataset:
#
# 2. Missing Data:
#
# No missing data is observed in either categorical or non-categorical variables, which indicates the dataset is complete.
# The missing data statistics for both records and features are provided, showing all entries have been accounted for.
#
#
# 3. Outlier Analysis:
#
# Outlier statistics for non-categorical variables indicate the presence of outliers in certain numerical features.
# The outlier treatment has been performed, where outliers have been adjusted or transformed.
#
#
# 4. Preprocessed Data:
#
# The preprocessed data section provides an insight into how the data looks after missing data treatment and outlier handling.
# All columns are numerical except for 'Order Date' and 'Ship Date', which are datetime objects.
#
#
# 5. Key Observations:
#
# The dataset comprises 100,001 records and 14 columns.
# The dataset spans multiple regions, countries, and item types, with sales occurring through various channels and with different priorities.
# Sales data ranges from 2010 to 2017.
# Units sold, unit price, unit cost, total revenue, total cost, and total profit are essential numerical features for sales analysis.
#
#
# 6. Recommendations:
#
# Further analysis could be conducted on sales trends over time, identifying top-performing regions, countries, or item types.
# Exploring the relationship between sales channel, order priority, and profitability could provide insights into optimizing sales strategies.
# Time series analysis on sales data could reveal seasonal trends or patterns.
# Customer segmentation analysis based on region or country could help tailor marketing strategies.
#
# Overview:
# The dataset provided consists of sales records with various features such as region, country, item type, sales channel, order priority, order date, etc. The data seems to be preprocessed, as there are no missing values or outliers. Below is an analysis of different aspects of the dataset:
#
# 2. Missing Data:
#
# No missing data is observed in either categorical or non-categorical variables, which indicates the dataset is complete.
# The missing data statistics for both records and features are provided, showing all entries have been accounted for.
# 3. Outlier Analysis:
#
# Outlier statistics for non-categorical variables indicate the presence of outliers in certain numerical features.
# The outlier treatment has been performed, where outliers have been adjusted or transformed.
# 4. Preprocessed Data:
#
# The preprocessed data section provides an insight into how the data looks after missing data treatment and outlier handling.
# All columns are numerical except for 'Order Date' and 'Ship Date', which are datetime objects.
# 5. Key Observations:
#
# The dataset comprises 100,000 records and 14 columns.
# The dataset spans multiple regions, countries, and item types, with sales occurring through various channels and with different priorities.
# Sales data ranges from 2010 to 2017.
# Units sold, unit price, unit cost, total revenue, total cost, and total profit are essential numerical features for sales analysis.
# 6. Recommendations:
#
# Further analysis could be conducted on sales trends over time, identifying top-performing regions, countries, or item types.
# Exploring the relationship between sales channel, order priority, and profitability could provide insights into optimizing sales strategies.
# Time series analysis on sales data could reveal seasonal trends or patterns.
# Customer segmentation analysis based on region or country could help tailor marketing strategies.
#
# The provided dataset is clean, with no missing values and outliers treated.
#
#
# # Results | Observations
#
# 1. Accuracy:
#
# The accuracy of the decision tree classifier model is approximately 23.81%. This indicates that the model correctly predicts the class label for about 23.81% of the instances in the dataset.
#
# 2. Classification Report:
#
#
# Precision: The average precision across all classes is approximately 0.24. Precision represents the ratio of correctly predicted positive observations to the total predicted positives.
# Recall: The average recall across all classes is approximately 0.24. Recall represents the ratio of correctly predicted positive observations to the all observations in actual class.
# F1-score: The average F1-score across all classes is approximately 0.24. F1-score is the harmonic mean of precision and recall.
# Support: The number of actual occurrences of each class in the dataset.
#
#
# 3. Confusion Matrix:
#
# The confusion matrix provides a detailed breakdown of the model's performance in terms of correctly and incorrectly classified instances for each class.
# Each row in the confusion matrix represents the instances in the actual class, while each column represents the instances in the predicted class.
#
#
# Predicted/Actual	  Class 0	Class 1	Class 2	 Class 3
# Class 0	              1729	1928	  1920	      1836
# Class 1	              1896	1781	  1874	      1887
# Class 2	              1916	1834	  1801	      1926
# Class 3	              1880	2049	  1910	      1833
#
#
# 4. Macro and Weighted Average:
#
# Macro Average: The macro average of precision, recall, and F1-score is approximately 0.24. It calculates the metric independently for each class and then takes the average, without considering class imbalance.
#
# Weighted Average: The weighted average of precision, recall, and F1-score is also approximately 0.24. It calculates the metric for each class and then takes the average, considering class imbalance by weighting the contribution of each class.
#
#
# 5. Execution Time and Memory Usage:
#
# The execution time for the decision tree classifier is approximately 5.63 seconds.
#
# The memory usage during the execution of the classifier is approximately 1,003,945,984 bytes.
#
#
# 6. Insights:
#
# The model's performance is consistent across different classes, with similar precision, recall, and F1-score values.
# The accuracy of 23.81% indicates that the model's performance might not be satisfactory and further optimization or improvement of the model may be required.
#
# The confusion matrix provides insights into the specific classes where the model performs well or poorly.
# The execution time and memory usage seem reasonable for the given dataset size.
#
#
# 7. Conclusion:
#
# While the decision tree classifier provides some level of predictive performance, the accuracy and overall performance metrics suggest room for improvement.
#
# Further analysis, optimization of model parameters, or exploration of alternative machine learning algorithms may be necessary to enhance the model's predictive capabilities.
#
#
# # Comparison between models
#
# 1. Decision Tree:
#
# Accuracy: 23.08%
# Precision, recall, and F1-score are relatively balanced across classes.
# Confusion matrix shows varied performance across different classes.
# Moderate accuracy and performance across classes.
#
#
# 2. Logistic Regression:
#
# Accuracy: 25.12%
# Precision, recall, and F1-score are relatively balanced across classes.
# Confusion matrix indicates better performance in classifying class 1.
# Slightly higher accuracy compared to the decision tree.
#
#
# 3. Support Vector Machine (SVM):
#
# Accuracy: 25.33%
# Precision, recall, and F1-score are relatively balanced across classes.
# Confusion matrix shows better performance in classifying class 1 and 3.
# Similar accuracy to logistic regression but with different class-wise performance.
#
#
# 4. K-Nearest Neighbors (KNN):
#
# Accuracy: 24.37%
# Precision, recall, and F1-score are relatively balanced across classes.
# Confusion matrix shows varied performance across different classes.
# Slightly lower accuracy compared to logistic regression and SVM.
#
#
# 5. Comparison:
#
# Accuracy: Logistic Regression and SVM have the highest accuracy among the models, followed by KNN and Decision Tree.
#
# Precision, Recall, F1-score: All models show relatively balanced precision, recall, and F1-score across classes.
#
# Confusion Matrix: Each model shows varied performance in classifying different classes, with no clear best performer across all classes.
#
# Computational Complexity: Decision Tree and Logistic Regression are generally faster to train compared to SVM and KNN.
#
# Interpretability: Decision Tree and Logistic Regression models are more interpretable compared to SVM and KNN.
#
# 6. Conclusion:
#
# Based on the provided data and the evaluation metrics, logistic regression and SVM appear to be the most appropriate models due to their relatively higher accuracy compared to the decision tree and KNN.
#
# However, further experimentation, hyperparameter tuning, and validation on additional datasets may be necessary to determine the best-performing model for the specific task at hand.
#
# It's also important to consider factors such as computational complexity, interpretability, and suitability to the problem domain when selecting the final model.
#
#
#
# # Results from comparing models
#
# 1. Accuracy Comparison:
#
# The accuracy of the models ranges from approximately 0.23 to 0.25. While some models like Logistic Regression and SVM have slightly higher accuracy (around 0.25), others like the Decision Tree and KNN models have slightly lower accuracy (around 0.23-0.24).
#
# This suggests that the choice of model impacts the overall predictive performance, with Logistic Regression and SVM performing marginally better in terms of overall accuracy.
#
# 2. Execution Time and Memory Usage:
#
# While not directly related to predictive performance, considering execution time and memory usage is crucial for practical deployment of the models, especially in real-time or resource-constrained environments.
#
# In this regard, Decision Tree and Logistic Regression models have relatively lower execution time and memory usage compared to SVM, which might make them more suitable for certain deployment scenarios.
#
# 3. Confusion Matrix Analysis:
#
#
# The confusion matrix provides insights into the performance of the models in terms of correctly and incorrectly classified instances for each class.
#
# For example, in the Decision Tree model, the confusion matrix indicates that class 0 and class 3 have relatively higher misclassifications compared to other classes
#
#
#
# 4. Recommendation for Model Selection:
#
# Based on the insights gathered, the Logistic Regression model stands out with slightly higher accuracy and balanced precision-recall trade-offs across classes.
#
# However, it's essential to consider other factors such as computational resources, interpretability, and the specific requirements of the application before finalizing the model selection.
#
#
# # Managerial Implications
#
# From the given findings, **Logistic Regression and SVM model** have relatively higher accuracy compared to others.
#
# Logistic Regression model also provides better precision, recall, and F1-score for most classes.
#
# Therefore, managers may consider Logistic Regression as a suitable classification model for their application.
#
# However, it's essential to conduct further evaluation and validation to ensure the chosen model aligns with the specific objectives and constraints of the business problem.
#
# **Using Logistic Regression and SVM models based on the findings can provide several benefits to managers in decision-making processes:**
#
# 1. Improved Classification Accuracy:
#
# Both Logistic Regression and SVM models demonstrated higher accuracy compared to other models in the analysis. By leveraging these models, managers can make more accurate predictions about the classification of consumer data into different segments or classes.
#
# This improved accuracy can lead to better-informed decisions and strategies.
#
# 2. Effective Segmentation of Consumer Data:
#
# Logistic Regression and SVM models can effectively segment consumer data into different classes based on relevant features such as region, country, item type, and sales channel.
#
# This segmentation allows managers to gain insights into consumer behavior, preferences, and purchase patterns, enabling them to tailor marketing strategies, product offerings, and customer services more effectively.
#
# 3. Identification of Important Features:
#
# These models can also identify important features or variables that significantly contribute to the classification process.
#
# By understanding which features are most influential in determining the order priority or consumer segments, managers can focus their efforts on optimizing those factors to enhance overall business performance.
#
# 4. Optimized Resource Allocation:
#
# Logistic Regression and SVM models provide insights into resource allocation by accurately predicting the order priority or consumer segments.
#
# Managers can allocate resources such as inventory, marketing budget, and customer support efforts more efficiently based on the predicted demand patterns and priorities identified by these models.
#
# 5. Risk Management and Fraud Detection:
#
# Logistic Regression and SVM models can be valuable tools for risk management and fraud detection.
#
# By analyzing historical data and identifying patterns indicative of fraudulent activities or high-risk transactions, managers can implement proactive measures to mitigate risks and protect the business from potential losses.
#
# 6. Enhanced Customer Experience:
#
# By leveraging insights derived from Logistic Regression and SVM models, managers can enhance the overall customer experience.
#
# Tailored marketing campaigns, personalized product recommendations, and targeted communication strategies can be developed based on the segmentation and classification results, leading to higher customer satisfaction and loyalty.
#
# Overall, utilizing Logistic Regression and SVM models can empower managers to make data-driven decisions, optimize business processes, and drive sustainable growth by leveraging the insights derived from the analysis of country sales data.
#
#
# To identify important, contributing, or significant variables or features and their thresholds for classification, we can analyze the findings from the Logistic Regression and SVM models. Here's how we can approach it:
#
#
# # Feature Importance Analysis:
#
# 1. For Logistic Regression:
#
#
# Examine the coefficients of the logistic regression model. Higher magnitude coefficients indicate more influential features.
# Identify features with the largest coefficients as they contribute more to the classification decision.
#
#
# For SVM:
#
#
# Analyze support vectors to identify features that are crucial for defining the decision boundary between classes.
#
#
# Coefficient Magnitudes:
#
# In Logistic Regression, features with larger coefficient magnitudes are considered more important.
# Identify the features with the highest absolute coefficient values as they have a stronger impact on the classification outcome.
# Feature Selection Techniques:
#
# Apply feature selection techniques such as recursive feature elimination (RFE) or regularization to Logistic Regression models.
# These techniques help identify the subset of features that are most relevant for classification.
#
#
# 2. Support Vector Analysis:
#
# Analyze support vectors from SVM models to identify features that are closest to the decision boundary.
#
# Features associated with support vectors are considered significant for classification.
#
# 3. Threshold Determination:
#
# Use ROC curve analysis to evaluate the performance of the classification models and determine optimal thresholds.
#
# Identify the threshold that maximizes the trade-off between true positive rate and false positive rate.
#
# This threshold will help classify instances into different classes effectively.
#
#
# 4. Domain Knowledge Integration:
#
#  Incorporate domain knowledge and expertise to validate the relevance of identified features.
#
# Consider business context and practical implications when determining thresholds for classification.
#
# By employing these approaches, managers can effectively identify important variables or features and their thresholds for classification.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9cda198-8fa1-46fa-9053-a0b05b0110fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9cda198-8fa1-46fa-9053-a0b05b0110fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the dataset
data = pd.read_excel("100000 Sales Records.xlsx")
data.info()

# Get the column names
columns = data.columns

# Initialize variables to store information
index_variables = []
outcome_variable = None
categorical_variables = {'Nominal': [], 'Ordinal': []}
non_categorical_variables = []

# Iterate through columns to classify variables
for col in columns:
    # Check if the column is an index variable
    if data.index.name == col:
        index_variables.append(col)
    # Check if the column is the outcome variable
    elif col == "Order Priority":
        outcome_variable = col
    # Check if the column is categorical
    elif data[col].dtype == 'object':
        unique_values = data[col].nunique()
        # Check if the column has nominal categories
        if unique_values > 2:
            categorical_variables['Nominal'].append(col)
        # Check if the column has ordinal categories
        elif unique_values == 2:
            categorical_variables['Ordinal'].append(col)
    # If the column is not categorical, it is non-categorical
    else:
        non_categorical_variables.append(col)

# Print the retrieved information
print("2.2. Description of Variables")
print("2.2.1. Index Variable(s):", index_variables)
print("2.2.2. Outcome Variable or Feature:", outcome_variable)
print("2.2.3. Input Variables or Features having Categories | Input Categorical Variables or Features (ICV):")
print("2.2.3.1. Input Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type:", categorical_variables['Nominal'])
print("2.2.3.2. Input Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type:", categorical_variables['Ordinal'])
print("2.2.3. Input Non-Categorical Variables or Features:", non_categorical_variables)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          100000 non-null  object
#  1   Country         100000 non-null  object
#  2   Item Type       100000 non-null  object
#  3   Sales Channel   100000 non-null  object
#  4   Order Priority  100000 non-null  object
#  5   Order Date      100000 non-null  datetime64[ns]
#  6   Order ID        100000 non-null  int64
#  7   Ship Date       100000 non-null  datetime64[ns]
#  8   Units Sold      100000 non-null  int64
#  9   Unit Price      100000 non-null  float64
#  10  Unit Cost       100000 non-null  float64
#  11  Total Revenue   100000 non-null  float64
#  12  Total Cost      100000 non-null  float64
#  13  Total Profit    100000 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 10.7+ MB
# ...

# %%
import pandas as pd

# Load the dataset
data = pd.read_excel("100000 Sales Records.xlsx")

# Descriptive statistics for the outcome variable
outcome_statistics_count = data['Order Priority'].value_counts()
outcome_statistics_proportion = data['Order Priority'].value_counts(normalize=True)

# Descriptive statistics for input categorical variables
categorical_variables = [col for col in data.columns if data[col].dtype == 'object']
categorical_statistics_count = data[categorical_variables].apply(lambda x: x.value_counts())
categorical_statistics_proportion = data[categorical_variables].apply(lambda x: x.value_counts(normalize=True))

# Descriptive statistics for input non-categorical variables
non_categorical_variables = [col for col in data.columns if col not in categorical_variables]
non_categorical_statistics_central_tendency = data[non_categorical_variables].mean()
non_categorical_statistics_median = data[non_categorical_variables].median()
non_categorical_statistics_dispersion = data[non_categorical_variables].describe().loc[['std', 'min', 'max']]
non_categorical_correlation_statistics = data[non_categorical_variables].corr()

# Print the retrieved information
print("2.3. Descriptive Statistics")
print("2.3.1. Descriptive Statistics: Outcome Variable or Feature (Categorical)")
print("2.3.1.1. Count | Frequency Statistics:")
print(outcome_statistics_count)
print("\n2.3.1.2. Proportion (Relative Frequency) Statistics:")
print(outcome_statistics_proportion)
print("\n2.3.2. Descriptive Statistics: Input Categorical Variables or Features")
print("2.3.2.1. Count | Frequency Statistics:")
print(categorical_statistics_count)
print("\n2.3.2.2. Proportion (Relative Frequency) Statistics:")
print(categorical_statistics_proportion)
print("\n2.3.3. Descriptive Statistics: Input Non-Categorical Variables or Features")
print("2.3.3.1. Measures of Central Tendency:")
print(non_categorical_statistics_central_tendency)
print("\n2.3.3.2. Measures of Dispersion:")
print(non_categorical_statistics_dispersion)
print("\n2.3.3.3. Correlation Statistics (with Test of Correlation):")
print(non_categorical_correlation_statistics)
# Out:
# 2.3. Descriptive Statistics
# 2.3.1. Descriptive Statistics: Outcome Variable or Feature (Categorical)
# 2.3.1.1. Count | Frequency Statistics:
# M    25088
# L    25016
# C    24951
# H    24945
# Name: Order Priority, dtype: int64
#
# 2.3.1.2. Proportion (Relative Frequency) Statistics:
# M    0.25088
# L    0.25016
# C    0.24951
# H    0.24945
# Name: Order Priority, dtype: float64
#
# 2.3.2. Descriptive Statistics: Input Categorical Variables or Features
# 2.3.2.1. Count | Frequency Statistics:
#              Region  Country  Item Type  Sales Channel  Order Priority
# Afghanistan     NaN    551.0        NaN            NaN             NaN
# Albania         NaN    521.0        NaN            NaN             NaN
# Algeria         NaN    520.0        NaN            NaN             NaN
# Andorra         NaN    535.0        NaN            NaN             NaN
# Angola          NaN    489.0        NaN            NaN             NaN
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np

# Load the dataset
data = pd.read_excel("100000 Sales Records.xlsx")

# 3.1.1. Missing Data Statistics and Treatment

# Missing Data Statistics: Records
missing_records = data.isnull().sum(axis=1)
print("3.1.1.1.1. Missing Data Statistics: Records")
print(missing_records)

# Missing Data Treatment: Records
data.dropna(thresh=len(data.columns)*0.5, inplace=True)
print("\n3.1.1.1.2. Missing Data Treatment: Records")
print(data)

# Missing Data Statistics: Categorical Variables or Features
missing_categorical = data.select_dtypes(include=['object']).isnull().sum()
print("\n3.1.1.2.1. Missing Data Statistics: Categorical Variables or Features")
print(missing_categorical)

# Missing Data Treatment: Categorical Variables or Features
imputer = SimpleImputer(strategy='most_frequent')
data_categorical = pd.DataFrame(imputer.fit_transform(data.select_dtypes(include=['object'])), columns=data.select_dtypes(include=['object']).columns)
data[data_categorical.columns] = data_categorical

# Missing Data Statistics: Non-Categorical Variables or Features
missing_non_categorical = data.select_dtypes(exclude=['object']).isnull().sum()
print("\n3.1.1.3.1. Missing Data Statistics: Non-Categorical Variables or Features")
print(missing_non_categorical)

# Missing Data Treatment: Non-Categorical Variables or Features
imputer = SimpleImputer(strategy='mean')
numeric_columns = data.select_dtypes(exclude=['object', 'datetime64']).columns
data_numeric = pd.DataFrame(imputer.fit_transform(data[numeric_columns]), columns=numeric_columns)

data[numeric_columns] = data_numeric

# 3.1.2. Numerical Encoding of Categorical Variables or Features
label_encoder = LabelEncoder()
for col in data.select_dtypes(include=['object']).columns:
    data[col] = label_encoder.fit_transform(data[col])

# 3.1.3. Outlier Statistics and Treatment
# Outlier Statistics: Non-Categorical Variables or Features
outlier_stats = data.select_dtypes(exclude=['object']).apply(lambda x: x.describe())
print("\n3.1.3.1.1. Outlier Statistics: Non-Categorical Variables or Features")
print(outlier_stats)

# Outlier Treatment: Non-Categorical Variables or Features
# Here, we perform outlier treatment by clipping values beyond 3 standard deviations from the mean
for col in data.select_dtypes(exclude=['object']).columns:
    mean = data[col].mean()
    std = data[col].std()
    data[col] = np.clip(data[col], mean - 3*std, mean + 3*std)

# 3.1.4. Data Bifurcation: Training & Testing Sets
X = data.drop(columns=['Order Priority'])
y = data['Order Priority']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 3.1.3.1.2. Outlier Treatment: Non-Categorical Variables or Features
print("\n3.1.3.1.2. Outlier Treatment: Non-Categorical Variables or Features")
print(data.select_dtypes(exclude=['object']).head())

# 3.1.3.1.2.1. Standardization: OV1, OV2, …
scaler = StandardScaler()
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
data_scaled = pd.DataFrame(scaler.fit_transform(data[numeric_columns]), columns=numeric_columns)


# 3.1.3.1.2.2. Normalization using Min-Max Scaler: OV3, OV4, …
scaler = MinMaxScaler()
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
data_normalized = pd.DataFrame(scaler.fit_transform(data[numeric_columns]), columns=numeric_columns)

# 3.1.3.1.2.3. Log Transformation: OV5, OV6, …
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
data_log_transformed = np.log(data[numeric_columns] + 1)  # Adding 1 to avoid log(0) error


# Display the pre-processed data
print("\nPre-processed data:")
print(data.head())
# Out:
# 3.1.1.1.1. Missing Data Statistics: Records
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Length: 100000, dtype: int64
#
# 3.1.1.1.2. Missing Data Treatment: Records
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# ...

# %%
import pandas as pd

# Define the columns to be concatenated
columns_to_concat = ['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority']

# Concatenate the specified columns into a single DataFrame
combined_df = df[columns_to_concat]

# Display the first few rows of the combined DataFrame
print(combined_df.head())
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority
# 0        Online              C
# 1       Offline              L
# 2       Offline              M
# 3        Online              M
# 4       Offline              H

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import time
import psutil

# Step 1: Load data
file_path = "100000 Sales Records.xlsx"
data = pd.read_excel(file_path)

# Step 2: Data Preprocessing
# Convert categorical variables to one-hot encoding
data_encoded = pd.get_dummies(data, columns=['Region', 'Country', 'Item Type', 'Sales Channel'])
data_encoded['Order Priority'] = pd.Categorical(data_encoded['Order Priority'], ordered=True, categories=['C', 'H', 'L', 'M'])
data_encoded['Order Priority'] = data_encoded['Order Priority'].cat.codes

# Drop unnecessary columns
data_preprocessed = data_encoded.drop(columns=['Order ID', 'Order Date', 'Ship Date'])

# Step 3: Split Data
X = data_preprocessed.drop(columns=["Order Priority"])
y = data_preprocessed["Order Priority"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 4: Train Decision Tree Classifier
clf_decision_tree = DecisionTreeClassifier()
start_time = time.time()
clf_decision_tree.fit(X_train, y_train)
end_time = time.time()
y_pred_decision_tree = clf_decision_tree.predict(X_test)

# Step 5: Evaluate Decision Tree Classifier
accuracy_decision_tree = accuracy_score(y_test, y_pred_decision_tree)
report_decision_tree = classification_report(y_test, y_pred_decision_tree)
matrix_decision_tree = confusion_matrix(y_test, y_pred_decision_tree)
memory_decision_tree = psutil.Process().memory_info().rss
execution_time_decision_tree = end_time - start_time

# Display results
print("Decision Tree Classifier Results:")
print("Accuracy:", accuracy_decision_tree)
print("Classification Report:")
print(report_decision_tree)
print("Confusion Matrix:")
print(matrix_decision_tree)
print("Execution Time:", execution_time_decision_tree)
print("Memory Usage:", memory_decision_tree)
# Out:
# Decision Tree Classifier Results:
# Accuracy: 0.23813333333333334
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.23      0.23      0.23      7413
#            1       0.23      0.24      0.24      7438
#            2       0.24      0.24      0.24      7477
#            3       0.24      0.24      0.24      7672
#
#     accuracy                           0.24     30000
#    macro avg       0.24      0.24      0.24     30000
# weighted avg       0.24      0.24      0.24     30000
#
# Confusion Matrix:
# [[1729 1928 1920 1836]
#  [1896 1781 1874 1887]
#  [1916 1834 1801 1926]
#  [1880 2049 1910 1833]]
# Execution Time: 5.628448247909546
# Memory Usage: 1003945984

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Load the data
data = pd.read_excel("100000 Sales Records.xlsx")

# Data Pre-processing
# Convert 'Order Priority' to numerical values
data['Order Priority'] = pd.Categorical(data['Order Priority'], ordered=True, categories=['C', 'H', 'L', 'M'])
data['Order Priority'] = data['Order Priority'].cat.codes

# Define features and target variable
X = data[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']]
y = data['Order Priority']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train Decision Tree model
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train, y_train)

# Train Logistic Regression model
log_reg_classifier = LogisticRegression(random_state=42)
log_reg_classifier.fit(X_train, y_train)

# Train SVM model
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)

# Train KNN model
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)

# Evaluate models
models = {
    'Decision Tree': dt_classifier,
    'Logistic Regression': log_reg_classifier,
    'SVM': svm_classifier,
    'KNN': knn_classifier
}

for name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    matrix = confusion_matrix(y_test, y_pred)

    print(f"Model: {name}")
    print("Accuracy:", accuracy)
    print("Classification Report:")
    print(report)
    print("Confusion Matrix:")
    print(matrix)
    print()

# Visualize the Decision Tree
plt.figure(figsize=(20,10))
plot_tree(dt_classifier, feature_names=X.columns, class_names=['C', 'H', 'L', 'M'], filled=True)
plt.show()
# Out:
# Model: Decision Tree
# Accuracy: 0.23076666666666668
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.23      0.27      0.25      7413
#            1       0.23      0.24      0.24      7438
#            2       0.23      0.22      0.22      7477
#            3       0.24      0.19      0.21      7672
#
#     accuracy                           0.23     30000
#    macro avg       0.23      0.23      0.23     30000
# weighted avg       0.23      0.23      0.23     30000
#
# Confusion Matrix:
# [[2022 2054 1794 1543]
#  [2333 1818 1800 1487]
#  [2283 2039 1622 1533]
#  [2286 2089 1836 1461]]
#
# Model: Logistic Regression
# Accuracy: 0.25116666666666665
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.24      0.08      0.12      7413
#            1       0.25      0.35      0.29      7438
#            2       0.25      0.31      0.28      7477
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import seaborn as sns  # Adding this import statement

# Load the data
data = pd.read_excel("100000 Sales Records.xlsx")

# Data Pre-processing
# Convert 'Order Priority' to numerical values
data['Order Priority'] = pd.Categorical(data['Order Priority'], ordered=True, categories=['C', 'H', 'L', 'M'])
data['Order Priority'] = data['Order Priority'].cat.codes

# Define features and target variable
X = data[['Units Sold', 'Unit Price', 'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit']]
y = data['Order Priority']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train Decision Tree model
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train, y_train)

# Train Logistic Regression model
log_reg_classifier = LogisticRegression(random_state=42)
log_reg_classifier.fit(X_train, y_train)

# Train SVM model
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)

# Train KNN model
knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(X_train, y_train)

# Evaluate models
models = {
    'Decision Tree': dt_classifier,
    'Logistic Regression': log_reg_classifier,
    'SVM': svm_classifier,
    'KNN': knn_classifier
}

for name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    matrix = confusion_matrix(y_test, y_pred)

    print(f"Model: {name}")
    print("Accuracy:", accuracy)
    print("Classification Report:")
    print(report)
    print("Confusion Matrix:")
    print(matrix)
    print()

# Visualize the Decision Tree
plt.figure(figsize=(20,10))
plot_tree(dt_classifier, feature_names=X.columns, class_names=['C', 'H', 'L', 'M'], filled=True)
plt.show()

# Define a function to plot confusion matrix
def plot_confusion_matrix(model_name, y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(f'Confusion Matrix - {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# Evaluate models and plot confusion matrices for KNN, SVM, and Logistic Regression
models_to_evaluate = {
    'KNN': knn_classifier,
    'SVM': svm_classifier,
    'Logistic Regression': log_reg_classifier
}

for name, model in models_to_evaluate.items():
    y_pred = model.predict(X_test)
    plot_confusion_matrix(name, y_test, y_pred)
# Out:
# Model: Decision Tree
# Accuracy: 0.23076666666666668
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.23      0.27      0.25      7413
#            1       0.23      0.24      0.24      7438
#            2       0.23      0.22      0.22      7477
#            3       0.24      0.19      0.21      7672
#
#     accuracy                           0.23     30000
#    macro avg       0.23      0.23      0.23     30000
# weighted avg       0.23      0.23      0.23     30000
#
# Confusion Matrix:
# [[2022 2054 1794 1543]
#  [2333 1818 1800 1487]
#  [2283 2039 1622 1533]
#  [2286 2089 1836 1461]]
#
# Model: Logistic Regression
# Accuracy: 0.25116666666666665
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.24      0.08      0.12      7413
#            1       0.25      0.35      0.29      7438
#            2       0.25      0.31      0.28      7477
# ...
